# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#1
thietbi=pd.read_csv('/PTDL/20056861_NgoThanhNam_TH02/thietbi.csv')
nguoidung_thietbi=pd.read_csv('/PTDL/20056861_NgoThanhNam_TH02/nguoidung_thietbi.csv')
nguoidung_sudung=pd.read_csv('/PTDL/20056861_NgoThanhNam_TH02/nguoidung_sudung.csv')

# %%
thietbi.rename(columns={'Retail Branding':'Branding','Marketing Name':'MarketingName'}, inplace=True)

# %%
dfKetQua = pd.merge(nguoidung_sudung,nguoidung_thietbi[['use_id','platform','device']],on='use_id')

# %%
dfKetQua.head(5)
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#   platform    device
# 0  android  GT-I9505
# 1  android  SM-G930F
# 2  android  SM-G930F
# 3  android     D2303
# 4  android  SM-G361F

# %%
#5
dfKetQua=pd.merge(dfKetQua, thietbi[['Branding','Model']], left_on='device', right_on='Model')

# %%
dfKetQua[dfKetQua.device.str.startswith('GT')].head(5)
# Out:
#     outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                     21.97                    4.82     1557.33   22787
# 8                     69.80                   14.70    25955.55   22801
# 10                   189.10                   24.08      519.12   22805
# 29                    85.97                   26.94      407.01   22831
# 52                    29.54                   34.78       33.79   22871
#
#    platform     device Branding      Model
# 0   android   GT-I9505  Samsung   GT-I9505
# 8   android   GT-I9505  Samsung   GT-I9505
# 10  android   GT-I9195  Samsung   GT-I9195
# 29  android  GT-I8190N  Samsung  GT-I8190N
# 52  android   GT-I9300  Samsung   GT-I9300

# %%
#7
dfKetQua.groupby('Branding').agg({
    'outgoing_mins_per_month':'mean',
    'outgoing_sms_per_month':'mean',
    'monthly_mb':'mean','use_id':'count'})
# Out:
#           outgoing_mins_per_month  outgoing_sms_per_month    monthly_mb  \
# Branding
# HTC                    299.842955               93.059318   5144.077955
# Huawei                  81.526667                9.500000   1561.226667
# LGE                    111.530000               12.760000   1557.330000
# Lava                    60.650000              261.900000  12458.670000
# Lenovo                 215.920000               12.930000   1557.330000
# Motorola                95.127500               65.666250   3946.500000
# OnePlus                354.855000               48.330000   6575.410000
# Samsung                191.010093               92.390463   4017.318889
# Sony                   177.315625               40.176250   3212.000625
# Vodafone                42.750000               46.830000   5191.120000
# ZTE                     42.750000               46.830000   5191.120000
#
#           use_id
# Branding
# HTC           44
# Huawei         3
# LGE            2
# ...

# %%
#8
sns.countplot(y='Branding',data=dfKetQua)
plt.show()

# %%
#9
# sns.barplot(x='count',y='Branding',data=dfKetQua)
# plt.show()
# Kết hợp dữ liệu
merged_df = nguoidung_thietbi_df.merge(nguoidung_df, on='use_id').merge(thietbi_df, on='device')

# Tính toán trung bình
average_usage = merged_df.groupby('Retail Branding').agg({
    'outgoing_mins_per_month': 'mean',
    'outgoing_sms_per_month': 'mean',
    'monthly_mb': 'mean'
}).reset_index()

# Đặt tên cột cho dễ hiểu
average_usage.columns = ['Retail Branding', 'Avg Call Minutes', 'Avg SMS', 'Avg Data MB']

# Thiết lập biểu đồ
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")

# Vẽ biểu đồ
average_usage.plot(x='Retail Branding', kind='bar', stacked=False, figsize=(14, 7))
plt.title('Average Call Minutes, SMS and Data Usage by Retail Branding')
plt.xlabel('Retail Branding')
plt.ylabel('Average Usage')
plt.xticks(rotation=45)
plt.legend(title='Usage Type')
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 #9
#       2 # sns.barplot(x='count',y='Branding',data=dfKetQua)
#       3 # plt.show()
#       4 # Kết hợp dữ liệu
# ----> 5 merged_df = nguoidung_thietbi_df.merge(nguoidung_df, on='use_id').merge(thietbi_df, on='device')
#       7 # Tính toán trung bình
#       8 average_usage = merged_df.groupby('Retail Branding').agg({
#       9     'outgoing_mins_per_month': 'mean',
#      10     'outgoing_sms_per_month': 'mean',
#      11     'monthly_mb': 'mean'
#      12 }).reset_index()
#
# NameError: name 'nguoidung_thietbi_df' is not defined

# %%
#10
sns.scatterplot(y='Branding',data=dfKetQua)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\namas\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1813, in Axis.convert_units(self, x)
#    1812 try:
# -> 1813     ret = self.converter.convert(x, self.units, self)
#    1814 except Exception as e:
#
# File c:\Users\namas\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File c:\Users\namas\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# ...

# %%
#11
from scipy import stats

t_statistic, p_value = stats.ttest_1samp(dfKetQua['Outgoing Minutes'], 200)
print(f'T-statistic: {t_statistic}, P-value: {p_value}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\namas\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Outgoing Minutes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 4
#       1 #11
# ...
